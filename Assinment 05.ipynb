# %%
import pandas as pd

# %% [markdown]
# Read the dataset from the below link

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv")

# %%
df1
# Out:
#          Unnamed: 0       Id       Name  Year Gender State  Count
# 0             11349    11350       Emma  2004      F    AK     62
# 1             11350    11351    Madison  2004      F    AK     48
# 2             11351    11352     Hannah  2004      F    AK     46
# 3             11352    11353      Grace  2004      F    AK     44
# 4             11353    11354      Emily  2004      F    AK     41
# 5             11354    11355    Abigail  2004      F    AK     37
# 6             11355    11356     Olivia  2004      F    AK     33
# 7             11356    11357   Isabella  2004      F    AK     30
# 8             11357    11358     Alyssa  2004      F    AK     29
# 9             11358    11359     Sophia  2004      F    AK     28
# 10            11359    11360     Alexis  2004      F    AK     27
# 11            11360    11361  Elizabeth  2004      F    AK     27
# 12            11361    11362     Hailey  2004      F    AK     27
# ...

# %% [markdown]
# # 1 Delete unnamed columns

# %%
df1.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df1
# Out:
#               Id       Name  Year Gender State  Count
# 0          11350       Emma  2004      F    AK     62
# 1          11351    Madison  2004      F    AK     48
# 2          11352     Hannah  2004      F    AK     46
# 3          11353      Grace  2004      F    AK     44
# 4          11354      Emily  2004      F    AK     41
# 5          11355    Abigail  2004      F    AK     37
# 6          11356     Olivia  2004      F    AK     33
# 7          11357   Isabella  2004      F    AK     30
# 8          11358     Alyssa  2004      F    AK     29
# 9          11359     Sophia  2004      F    AK     28
# 10         11360     Alexis  2004      F    AK     27
# 11         11361  Elizabeth  2004      F    AK     27
# 12         11362     Hailey  2004      F    AK     27
# 13         11363       Anna  2004      F    AK     26
# 14         11364    Natalie  2004      F    AK     25
# 15         11365      Sarah  2004      F    AK     25
# ...

# %% [markdown]
# # 2 Show the distribution of male and female

# %%
maleAndFemalCount = df1.groupby('Gender')

# %%
maleAndFemalCount.count()['Count']
# Out:
# Gender
# F    558846
# M    457549
# Name: Count, dtype: int64

# %% [markdown]
# # 3 Show the top 5 most preferred names

# %%
df1.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e55bb665ba13> in <module>()
# ----> 1 df1.head(5)
#
# NameError: name 'df1' is not defined

# %% [markdown]
# # 4 What is the median name occurence in the dataset

# %%
df1.groupby('Name')['Count'].median()
# Out:
# Name
# Aaban          6.0
# Aadan          5.5
# Aadarsh        5.0
# Aaden         10.0
# Aadhav         6.0
# Aadhya         8.0
# Aadi           7.0
# Aadin          5.0
# Aadit          6.0
# Aaditya        6.0
# Aadya          7.0
# Aadyn          6.0
# Aahan          7.0
# Aahana         7.0
# Aahil          7.0
# Aahna          7.0
# Aaiden         8.5
# Aaima          5.0
# Aakash         6.0
# Aalaya         5.0
# Aalayah        5.0
# Aaleah         5.0
# Aaleyah        6.0
# Aalia          5.0
# Aaliah         9.0
# Aalijah        5.0
# Aaliya         6.0
# Aaliyah       58.0
# Aaliyha        5.0
# Aalyah         7.5
#               ...
# Zyir           5.0
# Zyire          5.0
# Zykeria        9.0
# Zykeriah       5.0
# Zykerria       7.0
# Zykia          7.5
# Zykierra       5.0
# Zykira         7.0
# Zykiria        5.5
# Zyla           6.0
# Zylah          6.0
# Zylan          5.5
# Zylen          6.0
# Zyler          6.0
# Zymari         5.0
# Zymarion       5.0
# ...

# %% [markdown]
# # 5 Distribution of male and female born count by states

# %%
df_female = df1[df1['Gender']=='F'];df_female
# Out:
#               Id       Name  Year Gender State  Count
# 0          11350       Emma  2004      F    AK     62
# 1          11351    Madison  2004      F    AK     48
# 2          11352     Hannah  2004      F    AK     46
# 3          11353      Grace  2004      F    AK     44
# 4          11354      Emily  2004      F    AK     41
# 5          11355    Abigail  2004      F    AK     37
# 6          11356     Olivia  2004      F    AK     33
# 7          11357   Isabella  2004      F    AK     30
# 8          11358     Alyssa  2004      F    AK     29
# 9          11359     Sophia  2004      F    AK     28
# 10         11360     Alexis  2004      F    AK     27
# 11         11361  Elizabeth  2004      F    AK     27
# 12         11362     Hailey  2004      F    AK     27
# 13         11363       Anna  2004      F    AK     26
# 14         11364    Natalie  2004      F    AK     25
# 15         11365      Sarah  2004      F    AK     25
# ...

# %%
df_female['State'].value_counts()
# Out:
# CA    45144
# TX    39760
# NY    28158
# FL    25781
# IL    21268
# GA    19385
# OH    18143
# PA    17480
# NC    17357
# MI    16038
# NJ    15041
# VA    14759
# AZ    14518
# WA    13329
# TN    13063
# IN    13056
# MO    11948
# CO    11424
# MD    11276
# MN    10677
# MA    10580
# WI    10549
# LA    10510
# AL     9878
# OK     9519
# UT     9515
# SC     9465
# KY     8817
# OR     8604
# KS     7753
# MS     7235
# AR     7171
# IA     7131
# NV     7092
# CT     6575
# NM     5721
# NE     5370
# ID     4918
# WV     4305
# HI     3255
# DC     3053
# ME     2976
# NH     2957
# SD     2838
# MT     2690
# RI     2558
# DE     2549
# AK     2404
# ND     2399
# WY     1456
# VT     1398
# Name: State, dtype: int64

# %%
df_male = df1[df1['Gender']=='M'];df_male
# Out:
#               Id         Name  Year Gender State  Count
# 2404       24077        Ethan  2004      M    AK     65
# 2405       24078       Joseph  2004      M    AK     63
# 2406       24079        James  2004      M    AK     59
# 2407       24080        Jacob  2004      M    AK     54
# 2408       24081       Samuel  2004      M    AK     54
# 2409       24082        Tyler  2004      M    AK     54
# 2410       24083    Alexander  2004      M    AK     43
# 2411       24084       Joshua  2004      M    AK     43
# 2412       24085      Michael  2004      M    AK     43
# 2413       24086     Benjamin  2004      M    AK     42
# 2414       24087        David  2004      M    AK     42
# 2415       24088        Dylan  2004      M    AK     42
# 2416       24089      Gabriel  2004      M    AK     40
# 2417       24090       Connor  2004      M    AK     39
# 2418       24091       Daniel  2004      M    AK     39
# 2419       24092      Matthew  2004      M    AK     39
# ...

# %%
df_male['State'].value_counts()
# Out:
# CA    31637
# TX    27791
# NY    22585
# FL    20070
# IL    16828
# GA    15454
# OH    14318
# PA    14171
# NC    13530
# MI    13243
# NJ    12274
# VA    11997
# WA    11049
# AZ    10820
# IN    10613
# TN    10588
# MO     9917
# LA     9676
# MD     9483
# CO     9183
# MN     9004
# WI     8940
# MA     8609
# AL     8419
# UT     8233
# SC     8195
# OK     8138
# OR     7333
# KY     7267
# MS     6862
# KS     6748
# AR     6475
# IA     6307
# NV     6024
# CT     5733
# NE     5029
# NM     4966
# ID     4833
# WV     3733
# HI     3546
# DC     3000
# MT     2986
# SD     2908
# ME     2777
# NH     2659
# AK     2587
# ND     2581
# RI     2468
# DE     2440
# WY     1904
# VT     1618
# Name: State, dtype: int64

# %% [markdown]
# Task 2

# %%
import numpy as np
import matplotlib.pyplot as plt
Max= np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
Min= np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])
total_months = np.arange(1,13)

# %%
plt.plot(total_months, Max, 'ro-')
plt.plot(total_months, Min, 'bo-')
plt.xlabel('Month')
plt.ylabel('Temperature( C)')
# Out:
# Text(0,0.5,'Temperature( C)')
